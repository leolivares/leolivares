# %% [markdown]
# # Entrega 1 - Data Mining Project
# ## Integrantes
# * Wenyi He
# * Leonardo Olivares

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pre-Processing

# %%
df2017 = pd.read_csv("2017/survey_results_public.csv")
df2018 = pd.read_csv("2018/survey_results_public.csv")
# Out:
# /Users/EnriqueOlivares/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
column_2017 = list(df2017.columns.values)
column_2018 = list(df2018.columns.values)

# %%
df2017.rename(columns={
    'EmploymentStatus': 'Employment',
    'MajorUndergrad': 'UndergradMajor',
    'DeveloperType': 'DevType',
    'YearsProgram': 'YearsCoding',
    'YearsCodedJobPast' : 'YearsCodingProf',
    'JobSatisfaction' : 'JobSatisfaction',
    'CareerSatisfaction' : 'CareerSatisfaction',
    'JobSeekingStatus' : 'JobSearchStatus',
    'LastNewJob' : 'LastNewJob',
    'EducationTypes' : 'EducationTypes',
    'SelfTaughtTypes' : 'SelfTaughtTypes',
    'TimeAfterBootcamp' : 'TimeAfterBootcamp',
    'KinshipDevelopers' : 'AgreeDisagree1',
    'CompetePeers' : 'AgreeDisagree2',
    'HaveWorkedLanguage' : 'LanguageWorkedWith',
    'WantWorkLanguage' : 'LanguageDesireNextYear',
    'HaveWorkedDatabase' : 'DatabaseWorkedWith',
    'WantWorkDatabase' : 'DatabaseDesireNextYear',
    'HaveWorkedPlatform' : 'PlatformWorkedWith',
    'WantWorkPlatform' : 'PlatformDesireNextYear',
    'HaveWorkedFramework' : 'FrameworkWorkedWith',
    'WantWorkFramework' : 'FrameworkDesireNextYear',
    'IDE' : 'IDE',
    'Methodology' : 'Methodology',
    'VersionControl' : 'VersionControl',
    'CheckInCode' : 'CheckInCode',
    'Gender' : 'Gender',
    'HighestEducationParents' : 'EducationParents',
    'Race' : 'RaceEthnicity',
}, inplace=True)

# %%
df2017["SurveyYear"] = 2017
df2017["Hobby"] = False
df2017["OpenSource"] = False

# %%
df2018["SurveyYear"] = 2018

# %%
df2017.shape
# Out:
# (51392, 157)

# %%
for counter, option in enumerate(df2017["ProgramHobby"]):
    if option == 'Yes, both':
        df2017.set_value(counter, "Hobby", True)
        df2017.set_value(counter, "OpenSource", True)
    elif option == "Yes, I program as a hobby":
        df2017.set_value(counter, "Hobby", True)
    elif option == "Yes, I contribute to open source projects":
        df2017.set_value(counter, "OpenSource", True)

# %%
set_2017_2018 = [df2017, df2018]
df = pd.concat(set_2017_2018,  join="inner")
df = df.reset_index()

# %%
df = df.drop("Respondent", 1)
df.shape
# Out:
# (150247, 38)

# %%
# Set Hobby values to True or False
mask = df.Hobby == "Yes"
column_name = 'Hobby'
df.loc[mask, column_name] = True

mask = df.Hobby == "No"
column_name = 'Hobby'
df.loc[mask, column_name] = False

# %%
# Set OpenSource values to True or False
mask = df.OpenSource == "Yes"
column_name = 'OpenSource'
df.loc[mask, column_name] = True

mask = df.OpenSource == "No"
column_name = 'OpenSource'
df.loc[mask, column_name] = False

# %%
#DevType Columns
a = df["DevType"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_").replace("-", "_"))
    except AttributeError:
        continue

for i in lista_attr:
    df[i]=False

for c, i in enumerate(a):
    try:
        if isinstance(i, str):
            types = i.split(";")
            for l in types: 
                df.set_value(c, l.strip().replace(" ", "_").replace("-", "_"), True)
    except AttributeError:
        continue
        
#Remove DevType

df = df.drop("DevType", 1)

# %%
#Standardize YearsCoding values
changes = {
    'Less than a year': '0-2 years',
    '1 to 2 years': '0-2 years',
    '2 to 3 years': '0-2 years',
    '3 to 4 years': '3-5 years',
    '4 to 5 years': '3-5 years',
    '5 to 6 years': '3-5 years',
    '6 to 7 years': '6-8 years',
    '7 to 8 years': '6-8 years',
    '8 to 9 years': '6-8 years',
    '9 to 10 years': '9-11 years',
    '10 to 11 years': '9-11 years',
    '11 to 12 years': '9-11 years',
    '12 to 13 years': '12-14 years',
    '13 to 14 years': '12-14 years',
    '14 to 15 years': '12-14 years',
    '15 to 16 years': '15-17 years',
    '16 to 17 years': '15-17 years',
    '17 to 18 years': '15-17 years',
    '18 to 19 years': '18-20 years',
    '19 to 20 years': '18-20 years',
    '21-23 years': '20 or more years',
    '24-26 years': '20 or more years',
    '27-29 years': '20 or more years',
    '30 or more years': '20 or more years',
    True: np.nan
}


for year_range in changes :
    mask = df.YearsCoding == year_range
    column_name = 'YearsCoding'
    df.loc[mask, column_name] = changes[year_range]

# %%
#Standardize YearsCodingProf values
changes = {
    'Less than a year': '0-2 years',
    '1 to 2 years': '0-2 years',
    '2 to 3 years': '0-2 years',
    '3 to 4 years': '3-5 years',
    '4 to 5 years': '3-5 years',
    '5 to 6 years': '3-5 years',
    '6 to 7 years': '6-8 years',
    '7 to 8 years': '6-8 years',
    '8 to 9 years': '6-8 years',
    '9 to 10 years': '9-11 years',
    '10 to 11 years': '9-11 years',
    '11 to 12 years': '9-11 years',
    '12 to 13 years': '12-14 years',
    '13 to 14 years': '12-14 years',
    '14 to 15 years': '12-14 years',
    '15 to 16 years': '15-17 years',
    '16 to 17 years': '15-17 years',
    '17 to 18 years': '15-17 years',
    '18 to 19 years': '18-20 years',
    '19 to 20 years': '18-20 years',
    '21-23 years': '20 or more years',
    '24-26 years': '20 or more years',
    '27-29 years': '20 or more years',
    '30 or more years': '20 or more years',
    True: np.nan
}


for year_range in changes :
    mask = df.YearsCodingProf == year_range
    column_name = 'YearsCodingProf'
    df.loc[mask, column_name] = changes[year_range]

# %%
#Standardize JobSatisfaction and CareerSatisfaction values
changes = {
    0.0: 'Extremely dissatisfied',
    1.0: 'Moderately dissatisfied',
    2.0: 'Moderately dissatisfied',
    3.0: 'Slightly dissatisfied',
    4.0: 'Slightly dissatisfied',
    5.0: 'Neither satisfied nor dissatisfied',
    6.0: 'Slightly satisfied',
    7.0: 'Slightly satisfied',
    8.0: 'Moderately satisfied',
    9.0: 'Moderately satisfied',
    10.0: 'Extremely satisfied',
    True: np.nan
}


for satis in changes :
    mask = df.JobSatisfaction == satis
    column_name = 'JobSatisfaction'
    df.loc[mask, column_name] = changes[satis]
    
for satis in changes:
    mask = df.CareerSatisfaction == satis
    column_name = 'CareerSatisfaction'
    df.loc[mask, column_name] = changes[satis]

# %%
#Standardize JobSearchStatus values
changes = {
    "I'm not actively looking, but I am open to new opportunities": 'I’m not actively looking, but I am open to new opportunities',
    True: np.nan
}


for status in changes :
    mask = df.JobSearchStatus == status
    column_name = 'JobSearchStatus'
    df.loc[mask, column_name] = changes[status]

# %%
#Standardize LastNewJob values
changes = {
    "I've never had a job": 'Not applicable/ never',
    True: np.nan
}


for status in changes :
    mask = df.LastNewJob == status
    column_name = 'LastNewJob'
    df.loc[mask, column_name] = changes[status]

# %%
# Set Currency values
mask = df.Currency == True
column_name = 'Currency'
df.loc[mask, column_name] = np.nan

mask = df.Currency == 'Indian rupees (?)'
column_name = 'Currency'
df.loc[mask, column_name] = 'Indian rupees (₹)'

mask = df.Currency == 'Russian rubles (?)'
column_name = 'Currency'
df.loc[mask, column_name] = 'Russian rubles (₽)'

# %%
#SaLARIO, 
df = df.drop("Salary", 1)

# %%
#EducationTypes Valores muy distintos
df = df.drop("EducationTypes", 1)

# %%
#SelfTaughtTypes Valores muy distintos
df = df.drop('SelfTaughtTypes', 1)

# %%
# Set TimeAfterBootcamp values
mask = df.TimeAfterBootcamp == "I haven't gotten a job as a developer yet"
column_name = 'TimeAfterBootcamp'
df.loc[mask, column_name] = 'I haven’t gotten a developer job'

mask = df.TimeAfterBootcamp == 'I already had a full-time job as a developer when I began the program'
column_name = 'TimeAfterBootcamp'
df.loc[mask, column_name] = 'I already had a job as a developer when I started the program'

mask = df.TimeAfterBootcamp == 'Immediately upon graduating'
column_name = 'TimeAfterBootcamp'
df.loc[mask, column_name] = 'Immediately after graduating'

# %%
#AgreeDisagree 1 y 2
mask = df.AgreeDisagree1 == True
column_name = 'AgreeDisagree1'
df.loc[mask, column_name] = np.nan

mask = df.AgreeDisagree2 == True
column_name = 'AgreeDisagree2'
df.loc[mask, column_name] = np.nan

# %%
#LanguageWorkedWith Columns
a = df["LanguageWorkedWith"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_Worked")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_Worked", True)
    except AttributeError:
        continue
        
#Remove LanguageWorkedWith

df = df.drop("LanguageWorkedWith", 1)

# %%
#LanguageDesire Columns
a = df["LanguageDesireNextYear"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_Desire")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_Desire", True)
    except AttributeError:
        continue
        
#Remove LanguageWorkedWith

df = df.drop("LanguageDesireNextYear", 1)

# %%
#DatabaseWorkedWith Columns
a = df["DatabaseWorkedWith"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_DB_Worked")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_DB_Worked", True)
    except AttributeError:
        continue
        
#Remove LanguageWorkedWith

df = df.drop("DatabaseWorkedWith", 1)

# %%
#DatabaseDesireNextYear Columns
a = df["DatabaseDesireNextYear"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_DB_Desire")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_DB_Desire", True)
    except AttributeError:
        continue
        
#Remove LanguageWorkedWith

df = df.drop("DatabaseDesireNextYear", 1)

# %%
#PlatformWorkedWith Columns
a = df["PlatformWorkedWith"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_Plat_Worked")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_Plat_Worked", True)
    except AttributeError:
        continue
        
#Remove PlatformWorkedWith

df = df.drop("PlatformWorkedWith", 1)

# %%
#PlatformWorkedWith Columns
a = df["PlatformDesireNextYear"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_Plat_Desired")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_Plat_Desired", True)
    except AttributeError:
        continue
        
#Remove PlatformDesireNextYear

df = df.drop("PlatformDesireNextYear", 1)

# %%
#IDE Columns
a = df["IDE"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_IDE")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_IDE", True)
    except AttributeError:
        continue
        
#Remove IDE

df = df.drop("IDE", 1)

# %%
#FrameworkWorkedWith Columns
a = df["FrameworkWorkedWith"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_Frame_Worked")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_Frame_Worked", True)
    except AttributeError:
        continue
        
#Remove FrameworkWorkedWith

df = df.drop("FrameworkWorkedWith", 1)

# %%
#FrameworkDesireNextYear Columns
a = df["FrameworkDesireNextYear"]

lista_attr = set()
for i in a:

    try:
        k = i.split(";")
        for j in k:
            lista_attr.add(j.strip().replace(" ", "_")+"_Frame_Desire")
    except AttributeError:
        continue
        
for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        types = i.split(";")
        for l in types: 
            df.set_value(c, l.strip().replace(" ", "_")+"_Frame_Desire", True)
    except AttributeError:
        continue
        
#Remove FrameworkDesireNextYear

df = df.drop("FrameworkDesireNextYear", 1)

# %%
#Methodology Columns
a = df["Methodology"]

lista_attr = set()
for i in a:

    try:
        if isinstance(i, str):
            k = i.split(";")
            for j in k:
                lista_attr.add(j.strip().replace(" ", "_").replace("-", "_")+"_Method")
    except AttributeError:
        continue

for i in lista_attr:
    df[i]=False
    
for c, i in enumerate(a):
    try:
        if isinstance(i, str):
            types = i.split(";")
            for l in types: 
                df.set_value(c, l.strip().replace(" ", "_").replace("-", "_")+"_Method", True)
    except AttributeError:
        continue
        
#Remove Methodology

df = df.drop("Methodology", 1)

# %%
#VersionControl Columns
a = df["VersionControl"]

lista_attr = set()
for i in a:

    try:
        if isinstance(i, str):
            k = i.split(";")
            for j in k:
                lista_attr.add(j.strip().replace(" ", "_").replace("-", "_")+"_VC")
    except AttributeError:
        continue

for i in lista_attr:
    df[i]=False


for c, i in enumerate(a):
    try:
        if isinstance(i, str):
            types = i.split(";")
            for l in types: 
                df.set_value(c, l.strip().replace(" ", "_").replace("-", "_")+"_VC", True)
    except AttributeError:
        continue
        
#Remove VersionControl

df = df.drop("VersionControl", 1)

# %%
#Standardize CheckInCode values
changes = {
    'A few times per week': 'A few times a week',
    'Multiple times per day': 'Multiple times a day'
}


for satis in changes :
    mask = df.CheckInCode == satis
    column_name = 'CheckInCode'
    df.loc[mask, column_name] = changes[satis]
    
for satis in changes:
    mask = df.CheckInCode == satis
    column_name = 'CheckInCode'
    df.loc[mask, column_name] = changes[satis]

# %%
#Standardize EducationParents values
changes = {
    'Master’s degree (MA, MS, M.Eng., MBA, etc.)': "A master's degree",
    'Some college/university study without earning a degree': "Some college/university study, no bachelor's degree",
    'Professional degree (JD, MD, etc.)': 'A professional degree',
    'Bachelor’s degree (BA, BS, B.Eng., etc.)': "A bachelor's degree",
    'Other doctoral degree (Ph.D, Ed.D., etc.)': 'A doctoral degree',
    'They never completed any formal education': 'No education',
    'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)': 'High school'
    
}


for satis in changes :
    mask = df.EducationParents == satis
    column_name = 'EducationParents'
    df.loc[mask, column_name] = changes[satis]

# %%
#RaceEthnicity Columns
a = df["RaceEthnicity"]

lista_attr = set()
for i in a:

    try:
        if isinstance(i, str):
            k = i.split(";")
            for j in k:
                lista_attr.add(j.strip().replace(" ", "_").replace("-", "_")+"_Race")
    except AttributeError:
        continue

for i in lista_attr:
    df[i]=False

    
for c, i in enumerate(a):
    try:
        if isinstance(i, str):
            types = i.split(";")
            for l in types: 
                df.set_value(c, l.strip().replace(" ", "_").replace("-", "_")+"_Race", True)
    except AttributeError:
        continue
        
#Remove RaceEthnicity

df = df.drop("RaceEthnicity", 1)

# %%
df
# Out:
#         index  Hobby OpenSource                       Country  \
# 0           0   True       True                 United States
# 1           1   True       True                United Kingdom
# 2           2   True       True                United Kingdom
# 3           3   True       True                 United States
# 4           4   True      False                   Switzerland
# 5           5   True       True                   New Zealand
# 6           6   True       True                 United States
# 7           7   True       True                        Poland
# 8           8   True      False                      Colombia
# 9           9   True      False                        France
# 10         10   True      False                 United States
# 11         11  False      False                        Canada
# 12         12   True      False                United Kingdom
# 13         13   True       True                       Germany
# 14         14   True      False                United Kingdom
# 15         15   True      False                 United States
# 16         16   True       True                United Kingdom
# 17         17   True       True                 United States
# 18         18   True      False                 United States
# 19         19   True      False                        Greece
# 20         20   True      False                        Brazil
# 21         21   True      False                United Kingdom
# 22         22  False      False                        Israel
# 23         23   True       True                         Italy
# 24         24   True      False                       Belgium
# 25         25   True      False                 United States
# 26         26  False      False                         India
# 27         27   True      False                 United States
# 28         28   True       True                        Israel
# 29         29   True      False                 United States
# ...       ...    ...        ...                           ...
# 150217  98825   True      False                         India
# 150218  98826   True       True            Russian Federation
# 150219  98827   True      False                           NaN
# 150220  98828  False      False            Russian Federation
# 150221  98829   True       True                   Netherlands
# 150222  98830   True       True                         India
# 150223  98831   True      False            Russian Federation
# 150224  98832   True       True                   Netherlands
# 150225  98833   True      False                         India
# 150226  98834   True       True                        Poland
# 150227  98835   True       True                      Viet Nam
# 150228  98836   True       True  Iran, Islamic Republic of...
# 150229  98837   True      False                Czech Republic
# 150230  98838  False      False                        Poland
# 150231  98839   True       True                         India
# 150232  98840   True       True                         India
# 150233  98841  False      False                           NaN
# 150234  98842   True       True                      Pakistan
# 150235  98843   True      False                     Indonesia
# 150236  98844   True       True                         India
# 150237  98845  False       True                         India
# 150238  98846   True       True                    Azerbaijan
# 150239  98847  False      False                 United States
# 150240  98848   True      False                         India
# 150241  98849  False       True                         India
# 150242  98850   True       True                 United States
# 150243  98851  False       True                         Spain
# 150244  98852   True       True                         India
# 150245  98853   True      False            Russian Federation
# 150246  98854   True       True                      Cambodia
#
#                                                Employment  \
# 0                  Not employed, and not looking for work
# 1                                      Employed part-time
# 2                                      Employed full-time
# 3                                      Employed full-time
# 4                                      Employed full-time
# 5                  Not employed, and not looking for work
# 6                                      Employed full-time
# 7                                      Employed full-time
# 8                                      Employed full-time
# 9       Independent contractor, freelancer, or self-em...
# 10                                     Employed full-time
# 11                                     Employed full-time
# 12                     Not employed, but looking for work
# 13                                     Employed full-time
# 14                                     Employed full-time
# 15      Independent contractor, freelancer, or self-em...
# 16                 Not employed, and not looking for work
# 17                                     Employed full-time
# 18                                     Employed full-time
# 19                                     Employed full-time
# 20                                     Employed full-time
# 21                                     Employed full-time
# 22                                     Employed full-time
# 23      Independent contractor, freelancer, or self-em...
# 24                                     Employed full-time
# 25                                     Employed full-time
# 26                                     Employed full-time
# 27                                     Employed full-time
# 28                                     Employed full-time
# 29                                     Employed full-time
# ...                                                   ...
# 150217                                 Employed full-time
# 150218                                 Employed full-time
# 150219                                                NaN
# 150220                                 Employed full-time
# 150221                                 Employed part-time
# 150222                                 Employed full-time
# 150223                                                NaN
# 150224                                 Employed full-time
# 150225                 Not employed, but looking for work
# 150226             Not employed, and not looking for work
# 150227                                                NaN
# 150228                                 Employed full-time
# 150229  Independent contractor, freelancer, or self-em...
# 150230                                 Employed full-time
# 150231                                 Employed full-time
# 150232                                 Employed full-time
# 150233                                                NaN
# 150234                                 Employed full-time
# 150235                                                NaN
# 150236                                                NaN
# 150237                                 Employed full-time
# 150238                                 Employed full-time
# 150239                                                NaN
# 150240                                 Employed full-time
# 150241                                 Employed full-time
# 150242                                                NaN
# 150243                 Not employed, but looking for work
# 150244                                 Employed full-time
# 150245  Independent contractor, freelancer, or self-em...
# 150246                                                NaN
#
#                                           FormalEducation  \
# 0                                        Secondary school
# 1       Some college/university study without earning ...
# 2                                       Bachelor's degree
# 3                                         Doctoral degree
# 4                                         Master's degree
# 5                                        Secondary school
# 6                                         Master's degree
# 7                                         Master's degree
# 8                                       Bachelor's degree
# 9                                         Master's degree
# 10                                      Bachelor's degree
# 11                                      Bachelor's degree
# 12                                      Bachelor's degree
# 13      Some college/university study without earning ...
# 14                                    Professional degree
# 15                              Primary/elementary school
# 16                                       Secondary school
# 17                                      Bachelor's degree
# 18                                      Bachelor's degree
# 19                                        Doctoral degree
# 20                                      Bachelor's degree
# 21                                      Bachelor's degree
# 22                                      Bachelor's degree
# 23                                       Secondary school
# 24                                        Master's degree
# 25                                        Master's degree
# 26                                      Bachelor's degree
# 27                                      Bachelor's degree
# 28      Some college/university study without earning ...
# 29                                      Bachelor's degree
# ...                                                   ...
# 150217        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 150218  Some college/university study without earning ...
# 150219                                                NaN
# 150220                          Primary/elementary school
# 150221  Secondary school (e.g. American high school, G...
# 150222                                                NaN
# 150223                                                NaN
# 150224  Some college/university study without earning ...
# 150225           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150226                          Primary/elementary school
# 150227        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 150228             I never completed any formal education
# 150229                                                NaN
# 150230        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 150231        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 150232           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150233                                                NaN
# 150234  Some college/university study without earning ...
# 150235                                                NaN
# 150236                                                NaN
# 150237           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150238           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150239                                                NaN
# 150240           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150241           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150242                                                NaN
# 150243                                                NaN
# 150244           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 150245  Some college/university study without earning ...
# 150246                                                NaN
#
#                                            UndergradMajor  \
# 0                                                     NaN
# 1                Computer science or software engineering
# 2                Computer science or software engineering
# 3           A non-computer-focused engineering discipline
# 4                Computer science or software engineering
# 5                                                     NaN
# 6           A non-computer-focused engineering discipline
# 7                Computer science or software engineering
# 8                Computer science or software engineering
# 9                Computer science or software engineering
# 10                                       A social science
# 11               Computer science or software engineering
# 12                              Mathematics or statistics
# 13               Computer science or software engineering
# 14      Computer engineering or electrical/electronics...
# 15                                                    NaN
# 16                                                    NaN
# 17               Computer science or software engineering
# 18               Computer science or software engineering
# 19                                      A natural science
# 20               Computer science or software engineering
# 21                                      A natural science
# 22      Computer engineering or electrical/electronics...
# 23                                                    NaN
# 24               Computer science or software engineering
# 25               Computer science or software engineering
# 26               Computer science or software engineering
# 27                                  A business discipline
# 28      Computer engineering or electrical/electronics...
# 29                                  A business discipline
# ...                                                   ...
# 150217                                                NaN
# 150218                                                NaN
# 150219                                                NaN
# 150220                                                NaN
# 150221                                                NaN
# 150222                                                NaN
# 150223                                                NaN
# 150224                                                NaN
# 150225  Information systems, information technology, o...
# 150226                                                NaN
# 150227                                                NaN
# 150228                                                NaN
# 150229                                                NaN
# 150230                                                NaN
# 150231                                                NaN
# 150232                                                NaN
# 150233                                                NaN
# 150234                                                NaN
# 150235                                                NaN
# 150236                                                NaN
# 150237                                                NaN
# 150238                                                NaN
# 150239                                                NaN
# 150240                                                NaN
# 150241                                                NaN
# 150242                                                NaN
# 150243                                                NaN
# 150244                                                NaN
# 150245                                                NaN
# 150246                                                NaN
#
#                      CompanySize       YearsCoding YearsCodingProf  \
# 0                            NaN         0-2 years             NaN
# 1             20 to 99 employees        9-11 years             NaN
# 2       10,000 or more employees  20 or more years             NaN
# 3       10,000 or more employees       12-14 years             NaN
# 4             10 to 19 employees  20 or more years             NaN
# 5                            NaN         6-8 years             NaN
# 6             20 to 99 employees        9-11 years             NaN
# 7        Fewer than 10 employees        9-11 years             NaN
# 8       5,000 to 9,999 employees       12-14 years             NaN
# 9                            NaN       12-14 years             NaN
# 10          100 to 499 employees       12-14 years             NaN
# 11          100 to 499 employees       12-14 years             NaN
# 12                           NaN  20 or more years     15-17 years
# 13       Fewer than 10 employees       15-17 years             NaN
# 14      5,000 to 9,999 employees  20 or more years             NaN
# 15                           NaN        9-11 years             NaN
# 16                           NaN         6-8 years             NaN
# 17      1,000 to 4,999 employees  20 or more years             NaN
# 18      10,000 or more employees         0-2 years             NaN
# 19       Fewer than 10 employees       12-14 years             NaN
# 20      10,000 or more employees         3-5 years             NaN
# 21            20 to 99 employees  20 or more years             NaN
# 22          500 to 999 employees        9-11 years             NaN
# 23                           NaN        9-11 years             NaN
# 24            20 to 99 employees       18-20 years             NaN
# 25      10,000 or more employees  20 or more years             NaN
# 26      5,000 to 9,999 employees       12-14 years             NaN
# 27          100 to 499 employees         0-2 years             NaN
# 28            10 to 19 employees  20 or more years             NaN
# 29      10,000 or more employees         3-5 years             NaN
# ...                          ...               ...             ...
# 150217                       NaN               NaN             NaN
# 150218                       NaN               NaN             NaN
# 150219                       NaN               NaN             NaN
# 150220                       NaN               NaN             NaN
# 150221                       NaN               NaN             NaN
# 150222                       NaN               NaN             NaN
# 150223                       NaN               NaN             NaN
# 150224                       NaN               NaN             NaN
# 150225                       NaN         0-2 years       0-2 years
# 150226                       NaN         3-5 years             NaN
# 150227                       NaN               NaN             NaN
# 150228                       NaN               NaN             NaN
# 150229                       NaN               NaN             NaN
# 150230                       NaN               NaN             NaN
# 150231                       NaN               NaN             NaN
# 150232                       NaN               NaN             NaN
# 150233                       NaN               NaN             NaN
# 150234                       NaN               NaN             NaN
# 150235                       NaN               NaN             NaN
# 150236                       NaN               NaN             NaN
# 150237                       NaN               NaN             NaN
# 150238                       NaN               NaN             NaN
# 150239                       NaN               NaN             NaN
# 150240                       NaN               NaN             NaN
# 150241                       NaN               NaN             NaN
# 150242                       NaN               NaN             NaN
# 150243                       NaN         0-2 years       0-2 years
# 150244                       NaN               NaN             NaN
# 150245                       NaN               NaN             NaN
# 150246                       NaN               NaN             NaN
#
#              ...        Visual_Source_Safe_VC East_Asian_Race  \
# 0            ...                        False           False
# 1            ...                        False           False
# 2            ...                        False           False
# 3            ...                        False           False
# 4            ...                        False           False
# 5            ...                        False           False
# 6            ...                        False           False
# 7            ...                        False           False
# 8            ...                        False           False
# 9            ...                        False           False
# 10           ...                        False           False
# 11           ...                        False           False
# 12           ...                        False           False
# 13           ...                        False           False
# 14           ...                        False           False
# 15           ...                        False           False
# 16           ...                        False           False
# 17           ...                        False           False
# 18           ...                        False           False
# 19           ...                        False           False
# 20           ...                        False           False
# 21           ...                        False           False
# 22           ...                        False           False
# 23           ...                        False           False
# 24           ...                        False           False
# 25           ...                        False           False
# 26           ...                        False           False
# 27           ...                        False           False
# 28           ...                        False           False
# 29           ...                        False           False
# ...          ...                          ...             ...
# 150217       ...                        False           False
# 150218       ...                        False           False
# 150219       ...                        False           False
# 150220       ...                        False           False
# 150221       ...                        False           False
# 150222       ...                        False           False
# 150223       ...                        False           False
# 150224       ...                        False           False
# 150225       ...                        False           False
# 150226       ...                        False           False
# 150227       ...                        False           False
# 150228       ...                        False           False
# 150229       ...                        False           False
# 150230       ...                        False           False
# 150231       ...                        False           False
# 150232       ...                        False           False
# 150233       ...                        False           False
# 150234       ...                        False           False
# 150235       ...                        False           False
# 150236       ...                        False           False
# 150237       ...                        False           False
# 150238       ...                        False           False
# 150239       ...                        False           False
# 150240       ...                        False           False
# 150241       ...                        False           False
# 150242       ...                        False           False
# 150243       ...                        False           False
# 150244       ...                        False           False
# 150245       ...                        False           False
# 150246       ...                        False           False
#
#        Middle_Eastern_Race White_or_of_European_descent_Race  \
# 0                    False                              True
# 1                    False                              True
# 2                    False                              True
# 3                    False                              True
# 4                    False                             False
# 5                    False                              True
# 6                    False                              True
# 7                    False                              True
# 8                    False                             False
# 9                    False                              True
# 10                   False                              True
# 11                   False                             False
# 12                   False                              True
# 13                   False                             False
# 14                   False                              True
# 15                   False                              True
# 16                   False                              True
# 17                   False                              True
# 18                   False                             False
# 19                   False                             False
# 20                   False                             False
# 21                   False                              True
# 22                   False                              True
# 23                   False                              True
# 24                   False                             False
# 25                   False                              True
# 26                   False                             False
# 27                   False                             False
# 28                   False                              True
# 29                   False                             False
# ...                    ...                               ...
# 150217               False                             False
# 150218               False                             False
# 150219               False                             False
# 150220               False                             False
# 150221               False                             False
# 150222               False                             False
# 150223               False                             False
# 150224               False                             False
# 150225               False                             False
# 150226               False                             False
# 150227               False                             False
# 150228               False                             False
# 150229               False                             False
# 150230               False                             False
# 150231               False                             False
# 150232               False                             False
# 150233               False                             False
# 150234               False                             False
# 150235               False                             False
# 150236               False                             False
# 150237               False                             False
# 150238               False                             False
# 150239               False                             False
# 150240               False                             False
# 150241               False                             False
# 150242               False                             False
# 150243               False                             False
# 150244               False                             False
# 150245               False                             False
# 150246               False                             False
#
#        Black_or_of_African_descent_Race  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# 5                                 False
# 6                                 False
# 7                                 False
# 8                                 False
# 9                                 False
# 10                                False
# 11                                False
# 12                                False
# 13                                False
# 14                                False
# 15                                False
# 16                                False
# 17                                False
# 18                                False
# 19                                False
# 20                                False
# 21                                False
# 22                                False
# 23                                False
# 24                                False
# 25                                False
# 26                                False
# 27                                False
# 28                                False
# 29                                False
# ...                                 ...
# 150217                            False
# 150218                            False
# 150219                            False
# 150220                            False
# 150221                            False
# 150222                            False
# 150223                            False
# 150224                            False
# 150225                            False
# 150226                            False
# 150227                            False
# 150228                            False
# 150229                            False
# 150230                            False
# 150231                            False
# 150232                            False
# 150233                            False
# 150234                            False
# 150235                            False
# 150236                            False
# 150237                            False
# 150238                            False
# 150239                            False
# 150240                            False
# 150241                            False
# 150242                            False
# 150243                            False
# 150244                            False
# 150245                            False
# 150246                            False
#
#        Native_American,_Pacific_Islander,_or_Indigenous_Australian_Race  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# 5                                                   False
# 6                                                   False
# 7                                                   False
# 8                                                   False
# 9                                                   False
# 10                                                  False
# 11                                                  False
# 12                                                  False
# 13                                                  False
# 14                                                  False
# 15                                                  False
# 16                                                  False
# 17                                                   True
# 18                                                  False
# 19                                                  False
# 20                                                  False
# 21                                                  False
# 22                                                  False
# 23                                                  False
# 24                                                  False
# 25                                                  False
# 26                                                  False
# 27                                                  False
# 28                                                  False
# 29                                                  False
# ...                                                   ...
# 150217                                              False
# 150218                                              False
# 150219                                              False
# 150220                                              False
# 150221                                              False
# 150222                                              False
# 150223                                              False
# 150224                                              False
# 150225                                              False
# 150226                                              False
# 150227                                              False
# 150228                                              False
# 150229                                              False
# 150230                                              False
# 150231                                              False
# 150232                                              False
# 150233                                              False
# 150234                                              False
# 150235                                              False
# 150236                                              False
# 150237                                              False
# 150238                                              False
# 150239                                              False
# 150240                                              False
# 150241                                              False
# 150242                                              False
# 150243                                              False
# 150244                                              False
# 150245                                              False
# 150246                                              False
#
#        I_prefer_not_to_say_Race I_don’t_know_Race  \
# 0                         False             False
# 1                         False             False
# 2                         False             False
# 3                         False             False
# 4                         False             False
# 5                         False             False
# 6                         False             False
# 7                         False             False
# 8                         False             False
# 9                         False             False
# 10                        False             False
# 11                        False             False
# 12                        False             False
# 13                        False             False
# 14                        False             False
# 15                        False             False
# 16                        False             False
# 17                        False             False
# 18                        False             False
# 19                         True             False
# 20                        False             False
# 21                        False             False
# 22                        False             False
# 23                        False             False
# 24                        False             False
# 25                        False             False
# 26                        False             False
# 27                        False             False
# 28                        False             False
# 29                        False             False
# ...                         ...               ...
# 150217                    False             False
# 150218                    False             False
# 150219                    False             False
# 150220                    False             False
# 150221                    False             False
# 150222                    False             False
# 150223                    False             False
# 150224                    False             False
# 150225                    False             False
# 150226                    False             False
# 150227                    False             False
# 150228                    False             False
# 150229                    False             False
# 150230                    False             False
# 150231                    False             False
# 150232                    False             False
# 150233                    False             False
# 150234                    False             False
# 150235                    False             False
# 150236                    False             False
# 150237                    False             False
# 150238                    False             False
# 150239                    False             False
# 150240                    False             False
# 150241                    False             False
# 150242                    False             False
# 150243                    False             False
# 150244                    False             False
# 150245                    False             False
# 150246                    False             False
#
#        Hispanic_or_Latino/Latina_Race South_Asian_Race
# 0                               False            False
# 1                               False            False
# 2                               False            False
# 3                               False            False
# 4                               False            False
# 5                               False            False
# 6                               False            False
# 7                               False            False
# 8                                True            False
# 9                               False            False
# 10                              False            False
# 11                              False            False
# 12                              False            False
# 13                               True            False
# 14                              False            False
# 15                              False            False
# 16                              False            False
# 17                              False            False
# 18                              False            False
# 19                              False            False
# 20                              False            False
# 21                              False            False
# 22                              False            False
# 23                              False            False
# 24                              False            False
# 25                              False            False
# 26                              False            False
# 27                              False            False
# 28                              False            False
# 29                              False            False
# ...                               ...              ...
# 150217                          False            False
# 150218                          False            False
# 150219                          False            False
# 150220                          False            False
# 150221                          False            False
# 150222                          False            False
# 150223                          False            False
# 150224                          False            False
# 150225                          False            False
# 150226                          False            False
# 150227                          False            False
# 150228                          False            False
# 150229                          False            False
# 150230                          False            False
# 150231                          False            False
# 150232                          False            False
# 150233                          False            False
# 150234                          False            False
# 150235                          False            False
# 150236                          False            False
# 150237                          False            False
# 150238                          False            False
# 150239                          False            False
# 150240                          False            False
# 150241                          False            False
# 150242                          False            False
# 150243                          False            False
# 150244                          False            False
# 150245                          False            False
# 150246                          False            False
#
# [150247 rows x 325 columns]

# %%
df.isnull().sum(axis=1)
# Out:
# 0          8
# 1          8
# 2          4
# 3          3
# 4         10
# 5         10
# 6          6
# 7          5
# 8          3
# 9          6
# 10         5
# 11         9
# 12         6
# 13         5
# 14         4
# 15         5
# 16         6
# 17         3
# 18         7
# 19         4
# 20         9
# 21         3
# 22         4
# 23         9
# 24        10
# 25         3
# 26         6
# 27        10
# 28         4
# 29        10
#           ..
# 150217    15
# 150218    15
# 150219    18
# 150220    15
# 150221    15
# 150222    16
# 150223    17
# 150224    15
# 150225    12
# 150226    14
# 150227    16
# 150228    15
# 150229    16
# 150230    15
# 150231    15
# 150232    15
# 150233    18
# 150234    15
# 150235    17
# 150236    17
# 150237    15
# 150238    15
# 150239    17
# 150240    15
# 150241    15
# 150242    17
# 150243    14
# 150244    15
# 150245    15
# 150246    17
# dtype: int64

# %%
df.shape
# Out:
# (150247, 325)

# %%
for i, c in enumerate(df.columns.unique()):
    print(i, c)
# Out:
# 0 index
# 1 Hobby
# 2 OpenSource
# 3 Country
# 4 Employment
# 5 FormalEducation
# 6 UndergradMajor
# 7 CompanySize
# 8 YearsCoding
# 9 YearsCodingProf
# 10 JobSatisfaction
# 11 CareerSatisfaction
# 12 JobSearchStatus
# 13 LastNewJob
# 14 Currency
# 15 TimeAfterBootcamp
# 16 AgreeDisagree1
# 17 AgreeDisagree2
# 18 CheckInCode
# 19 Gender
# 20 EducationParents
# 21 SurveyYear
# 22 Other
# 23 Designer
# 24 System_administrator
# 25 Product_manager
# 26 Graphics_programming
# 27 Marketing_or_sales_professional
# 28 Database_administrator
# 29 Full_stack_developer
# 30 C_suite_executive_(CEO,_CTO,_etc.)
# 31 DevOps_specialist
# 32 Data_or_business_analyst
# 33 Back_end_developer
# 34 Engineering_manager
# 35 Educator_or_academic_researcher
# 36 Developer_with_a_statistics_or_mathematics_background
# 37 Desktop_applications_developer
# 38 Front_end_developer
# 39 Graphic_designer
# 40 Data_scientist
# 41 Data_scientist_or_machine_learning_specialist
# 42 Game_or_graphics_developer
# 43 QA_or_test_developer
# 44 Quality_assurance_engineer
# 45 Student
# 46 Mobile_developer
# 47 Machine_learning_specialist
# 48 Systems_administrator
# 49 Embedded_applications_or_devices_developer
# 50 Embedded_applications/devices_developer
# 51 Web_developer
# 52 Desktop_or_enterprise_applications_developer
# 53 Cobol_Worked
# 54 C_Worked
# 55 Java_Worked
# 56 Objective-C_Worked
# 57 Go_Worked
# 58 Elixir_Worked
# 59 SQL_Worked
# 60 CSS_Worked
# 61 F#_Worked
# 62 HTML_Worked
# 63 Swift_Worked
# 64 C++_Worked
# 65 Visual_Basic_6_Worked
# 66 Scala_Worked
# 67 R_Worked
# 68 Hack_Worked
# 69 Lua_Worked
# 70 Smalltalk_Worked
# 71 Perl_Worked
# 72 Clojure_Worked
# 73 Delphi/Object_Pascal_Worked
# 74 VBA_Worked
# 75 Ruby_Worked
# 76 Common_Lisp_Worked
# 77 VB.NET_Worked
# 78 Python_Worked
# 79 Bash/Shell_Worked
# 80 Julia_Worked
# 81 Haskell_Worked
# 82 Kotlin_Worked
# 83 Rust_Worked
# 84 JavaScript_Worked
# 85 Ocaml_Worked
# 86 C#_Worked
# 87 Erlang_Worked
# 88 Groovy_Worked
# 89 PHP_Worked
# 90 Matlab_Worked
# 91 CoffeeScript_Worked
# 92 Assembly_Worked
# 93 Dart_Worked
# 94 TypeScript_Worked
# 95 Perl_Desire
# 96 Visual_Basic_6_Desire
# 97 Rust_Desire
# 98 Erlang_Desire
# 99 Haskell_Desire
# 100 Kotlin_Desire
# 101 Groovy_Desire
# 102 C++_Desire
# 103 Common_Lisp_Desire
# 104 Assembly_Desire
# 105 TypeScript_Desire
# 106 Delphi/Object_Pascal_Desire
# 107 Python_Desire
# 108 Cobol_Desire
# 109 JavaScript_Desire
# 110 SQL_Desire
# 111 Java_Desire
# 112 Julia_Desire
# 113 Scala_Desire
# 114 R_Desire
# 115 F#_Desire
# 116 Elixir_Desire
# 117 Hack_Desire
# 118 CSS_Desire
# 119 Ruby_Desire
# 120 CoffeeScript_Desire
# 121 PHP_Desire
# 122 C_Desire
# 123 VB.NET_Desire
# 124 VBA_Desire
# 125 Lua_Desire
# 126 Go_Desire
# 127 Smalltalk_Desire
# 128 C#_Desire
# 129 Swift_Desire
# 130 Dart_Desire
# 131 Objective-C_Desire
# 132 Bash/Shell_Desire
# 133 HTML_Desire
# 134 Matlab_Desire
# 135 Ocaml_Desire
# 136 Clojure_Desire
# 137 SQLite_DB_Worked
# 138 Apache_Hive_DB_Worked
# 139 Oracle_DB_Worked
# 140 PostgreSQL_DB_Worked
# 141 MariaDB_DB_Worked
# 142 IBM_Db2_DB_Worked
# 143 Apache_HBase_DB_Worked
# 144 Amazon_RDS/Aurora_DB_Worked
# 145 Cassandra_DB_Worked
# 146 Google_Cloud_Storage_DB_Worked
# 147 Memcached_DB_Worked
# 148 Redis_DB_Worked
# 149 SQL_Server_DB_Worked
# 150 Microsoft_Azure_(Tables,_CosmosDB,_SQL,_etc)_DB_Worked
# 151 MongoDB_DB_Worked
# 152 Amazon_DynamoDB_DB_Worked
# 153 MySQL_DB_Worked
# 154 Elasticsearch_DB_Worked
# 155 Amazon_Redshift_DB_Worked
# 156 Neo4j_DB_Worked
# 157 Google_BigQuery_DB_Worked
# 158 Apache_Hive_DB_Desire
# 159 Oracle_DB_Desire
# 160 MongoDB_DB_Desire
# 161 Memcached_DB_Desire
# 162 Cassandra_DB_Desire
# 163 MySQL_DB_Desire
# 164 MariaDB_DB_Desire
# 165 SQLite_DB_Desire
# 166 Redis_DB_Desire
# 167 Google_Cloud_Storage_DB_Desire
# 168 SQL_Server_DB_Desire
# 169 Microsoft_Azure_(Tables,_CosmosDB,_SQL,_etc)_DB_Desire
# 170 Amazon_Redshift_DB_Desire
# 171 IBM_Db2_DB_Desire
# 172 Neo4j_DB_Desire
# 173 Amazon_DynamoDB_DB_Desire
# 174 Google_BigQuery_DB_Desire
# 175 Amazon_RDS/Aurora_DB_Desire
# 176 Elasticsearch_DB_Desire
# 177 Apache_HBase_DB_Desire
# 178 PostgreSQL_DB_Desire
# 179 Amazon_Web_Services_(AWS)_Plat_Worked
# 180 Arduino_Plat_Worked
# 181 AWS_Plat_Worked
# 182 Android_Plat_Worked
# 183 WordPress_Plat_Worked
# 184 SharePoint_Plat_Worked
# 185 Windows_Desktop_or_Server_Plat_Worked
# 186 Google_Cloud_Platform/App_Engine_Plat_Worked
# 187 Mainframe_Plat_Worked
# 188 Windows_Desktop_Plat_Worked
# 189 Predix_Plat_Worked
# 190 Google_Home_Plat_Worked
# 191 Apple_Watch_or_Apple_TV_Plat_Worked
# 192 Amazon_Echo_Plat_Worked
# 193 Drupal_Plat_Worked
# 194 Heroku_Plat_Worked
# 195 Gaming_console_Plat_Worked
# 196 Raspberry_Pi_Plat_Worked
# 197 ESP8266_Plat_Worked
# 198 Linux_Desktop_Plat_Worked
# 199 Salesforce_Plat_Worked
# 200 Mac_OS_Plat_Worked
# 201 iOS_Plat_Worked
# 202 Firebase_Plat_Worked
# 203 IBM_Cloud_or_Watson_Plat_Worked
# 204 Linux_Plat_Worked
# 205 Microsoft_Azure_Plat_Worked
# 206 Serverless_Plat_Worked
# 207 Azure_Plat_Worked
# 208 Windows_Phone_Plat_Worked
# 209 iOS_Plat_Desired
# 210 AWS_Plat_Desired
# 211 Gaming_console_Plat_Desired
# 212 Arduino_Plat_Desired
# 213 Amazon_Echo_Plat_Desired
# 214 Firebase_Plat_Desired
# 215 Android_Plat_Desired
# 216 Azure_Plat_Desired
# 217 Windows_Phone_Plat_Desired
# 218 Google_Cloud_Platform/App_Engine_Plat_Desired
# 219 SharePoint_Plat_Desired
# 220 Mainframe_Plat_Desired
# 221 Mac_OS_Plat_Desired
# 222 Linux_Plat_Desired
# 223 Drupal_Plat_Desired
# 224 Linux_Desktop_Plat_Desired
# 225 Windows_Desktop_or_Server_Plat_Desired
# 226 Serverless_Plat_Desired
# 227 Amazon_Web_Services_(AWS)_Plat_Desired
# 228 Apple_Watch_or_Apple_TV_Plat_Desired
# 229 IBM_Cloud_or_Watson_Plat_Desired
# 230 Google_Home_Plat_Desired
# 231 Windows_Desktop_Plat_Desired
# 232 Salesforce_Plat_Desired
# 233 Microsoft_Azure_Plat_Desired
# 234 Heroku_Plat_Desired
# 235 WordPress_Plat_Desired
# 236 Raspberry_Pi_Plat_Desired
# 237 Predix_Plat_Desired
# 238 ESP8266_Plat_Desired
# 239 Light_Table_IDE
# 240 NetBeans_IDE
# 241 RubyMine_IDE
# 242 Zend_IDE
# 243 Emacs_IDE
# 244 Eclipse_IDE
# 245 IPython_/_Jupyter_IDE
# 246 Notepad++_IDE
# 247 Atom_IDE
# 248 Coda_IDE
# 249 PHPStorm_IDE
# 250 Android_Studio_IDE
# 251 Visual_Studio_Code_IDE
# 252 Sublime_Text_IDE
# 253 PyCharm_IDE
# 254 Komodo_IDE
# 255 Vim_IDE
# 256 IntelliJ_IDE
# 257 RStudio_IDE
# 258 Xcode_IDE
# 259 Visual_Studio_IDE
# 260 TextMate_IDE
# 261 Node.js_Frame_Worked
# 262 Firebase_Frame_Worked
# 263 Angular_Frame_Worked
# 264 React_Frame_Worked
# 265 Django_Frame_Worked
# 266 Torch/PyTorch_Frame_Worked
# 267 Spark_Frame_Worked
# 268 Spring_Frame_Worked
# 269 Cordova_Frame_Worked
# 270 Xamarin_Frame_Worked
# 271 Hadoop_Frame_Worked
# 272 AngularJS_Frame_Worked
# 273 .NET_Core_Frame_Worked
# 274 TensorFlow_Frame_Worked
# 275 AngularJS_Frame_Desire
# 276 Hadoop_Frame_Desire
# 277 Xamarin_Frame_Desire
# 278 Spring_Frame_Desire
# 279 React_Frame_Desire
# 280 Torch/PyTorch_Frame_Desire
# 281 Spark_Frame_Desire
# 282 Django_Frame_Desire
# 283 TensorFlow_Frame_Desire
# 284 .NET_Core_Frame_Desire
# 285 Node.js_Frame_Desire
# 286 Firebase_Frame_Desire
# 287 Cordova_Frame_Desire
# 288 Angular_Frame_Desire
# 289 Evidence_based_software_engineering_Method
# 290 Agile_Method
# 291 Extreme_programming_(XP)_Method
# 292 Domain_driven_design_Method
# 293 PRINCE2_Method
# 294 Mob_Method
# 295 Formal_standard_such_as_ISO_9001_or_IEEE_12207_(aka_“waterfall”_methodologies)_Method
# 296 Extreme_Method
# 297 Waterfall_Method
# 298 Scrum_Method
# 299 Evidence_based_SWE_Method
# 300 Kanban_Method
# 301 Pair_Method
# 302 Pair_programming_Method
# 303 Mob_programming_Method
# 304 Lean_Method
# 305 Team_Foundation_Version_Control_VC
# 306 Zip_file_back_ups_VC
# 307 Rational_ClearCase_VC
# 308 Git_VC
# 309 Subversion_VC
# 310 I_don't_use_version_control_VC
# 311 Copying_and_pasting_files_to_network_shares_VC
# 312 I_use_some_other_system_VC
# 313 Team_Foundation_Server_VC
# 314 Mercurial_VC
# 315 Visual_Source_Safe_VC
# 316 I_don’t_know_Race
# 317 East_Asian_Race
# 318 Native_American,_Pacific_Islander,_or_Indigenous_Australian_Race
# 319 Black_or_of_African_descent_Race
# 320 Middle_Eastern_Race
# 321 Hispanic_or_Latino/Latina_Race
# 322 White_or_of_European_descent_Race
# 323 I_prefer_not_to_say_Race
# 324 South_Asian_Race

# %%
# Cantidad de valores non-nan por fila
df.dropna(thresh=315)
# Out:
#         index  Hobby OpenSource             Country  \
# 0           0   True       True       United States
# 1           1   True       True      United Kingdom
# 2           2   True       True      United Kingdom
# 3           3   True       True       United States
# 4           4   True      False         Switzerland
# 5           5   True       True         New Zealand
# 6           6   True       True       United States
# 7           7   True       True              Poland
# 8           8   True      False            Colombia
# 9           9   True      False              France
# 10         10   True      False       United States
# 11         11  False      False              Canada
# 12         12   True      False      United Kingdom
# 13         13   True       True             Germany
# 14         14   True      False      United Kingdom
# 15         15   True      False       United States
# 16         16   True       True      United Kingdom
# 17         17   True       True       United States
# 18         18   True      False       United States
# 19         19   True      False              Greece
# 20         20   True      False              Brazil
# 21         21   True      False      United Kingdom
# 22         22  False      False              Israel
# 23         23   True       True               Italy
# 24         24   True      False             Belgium
# 25         25   True      False       United States
# 26         26  False      False               India
# 27         27   True      False       United States
# 28         28   True       True              Israel
# 29         29   True      False       United States
# ...       ...    ...        ...                 ...
# 141892  90500   True       True       United States
# 141893  90501  False       True  Russian Federation
# 141894  90502  False      False       United States
# 141895  90503   True      False               Spain
# 141896  90504   True      False      United Kingdom
# 141897  90505  False       True              Canada
# 141899  90507  False      False               India
# 141901  90509  False      False               Italy
# 141902  90510   True      False      United Kingdom
# 141904  90512   True      False               India
# 141905  90513   True       True              Canada
# 141906  90514   True      False               India
# 141907  90515   True      False             Germany
# 141911  90519   True      False  Russian Federation
# 141912  90520   True      False       United States
# 141913  90521   True      False              Sweden
# 141915  90523   True      False              Israel
# 141918  90526   True      False             Austria
# 141919  90527  False      False       United States
# 141921  90529   True      False              Poland
# 141922  90530   True      False              Poland
# 141923  90531  False       True               India
# 141925  90533   True      False              Canada
# 141926  90534   True      False               Chile
# 141927  90535   True      False      Czech Republic
# 141928  90536   True      False              France
# 141931  90539   True      False               India
# 141933  90541   True      False            Malaysia
# 141935  90543   True      False              Turkey
# 141936  90544   True       True      United Kingdom
#
#                                                Employment  \
# 0                  Not employed, and not looking for work
# 1                                      Employed part-time
# 2                                      Employed full-time
# 3                                      Employed full-time
# 4                                      Employed full-time
# 5                  Not employed, and not looking for work
# 6                                      Employed full-time
# 7                                      Employed full-time
# 8                                      Employed full-time
# 9       Independent contractor, freelancer, or self-em...
# 10                                     Employed full-time
# 11                                     Employed full-time
# 12                     Not employed, but looking for work
# 13                                     Employed full-time
# 14                                     Employed full-time
# 15      Independent contractor, freelancer, or self-em...
# 16                 Not employed, and not looking for work
# 17                                     Employed full-time
# 18                                     Employed full-time
# 19                                     Employed full-time
# 20                                     Employed full-time
# 21                                     Employed full-time
# 22                                     Employed full-time
# 23      Independent contractor, freelancer, or self-em...
# 24                                     Employed full-time
# 25                                     Employed full-time
# 26                                     Employed full-time
# 27                                     Employed full-time
# 28                                     Employed full-time
# 29                                     Employed full-time
# ...                                                   ...
# 141892                                                NaN
# 141893                                 Employed full-time
# 141894                                            Retired
# 141895  Independent contractor, freelancer, or self-em...
# 141896  Independent contractor, freelancer, or self-em...
# 141897                                                NaN
# 141899             Not employed, and not looking for work
# 141901  Independent contractor, freelancer, or self-em...
# 141902  Independent contractor, freelancer, or self-em...
# 141904                 Not employed, but looking for work
# 141905                                 Employed full-time
# 141906                                 Employed part-time
# 141907             Not employed, and not looking for work
# 141911             Not employed, and not looking for work
# 141912                 Not employed, but looking for work
# 141913                                 Employed full-time
# 141915             Not employed, and not looking for work
# 141918             Not employed, and not looking for work
# 141919                                            Retired
# 141921                 Not employed, but looking for work
# 141922                 Not employed, but looking for work
# 141923                 Not employed, but looking for work
# 141925  Independent contractor, freelancer, or self-em...
# 141926                                 Employed part-time
# 141927                                                NaN
# 141928                                            Retired
# 141931             Not employed, and not looking for work
# 141933                                            Retired
# 141935                 Not employed, but looking for work
# 141936                                                NaN
#
#                                           FormalEducation  \
# 0                                        Secondary school
# 1       Some college/university study without earning ...
# 2                                       Bachelor's degree
# 3                                         Doctoral degree
# 4                                         Master's degree
# 5                                        Secondary school
# 6                                         Master's degree
# 7                                         Master's degree
# 8                                       Bachelor's degree
# 9                                         Master's degree
# 10                                      Bachelor's degree
# 11                                      Bachelor's degree
# 12                                      Bachelor's degree
# 13      Some college/university study without earning ...
# 14                                    Professional degree
# 15                              Primary/elementary school
# 16                                       Secondary school
# 17                                      Bachelor's degree
# 18                                      Bachelor's degree
# 19                                        Doctoral degree
# 20                                      Bachelor's degree
# 21                                      Bachelor's degree
# 22                                      Bachelor's degree
# 23                                       Secondary school
# 24                                        Master's degree
# 25                                        Master's degree
# 26                                      Bachelor's degree
# 27                                      Bachelor's degree
# 28      Some college/university study without earning ...
# 29                                      Bachelor's degree
# ...                                                   ...
# 141892          Other doctoral degree (Ph.D, Ed.D., etc.)
# 141893  Some college/university study without earning ...
# 141894           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141895                          Primary/elementary school
# 141896           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141897  Some college/university study without earning ...
# 141899           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141901          Other doctoral degree (Ph.D, Ed.D., etc.)
# 141902  Some college/university study without earning ...
# 141904          Other doctoral degree (Ph.D, Ed.D., etc.)
# 141905           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141906           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141907             I never completed any formal education
# 141911                          Primary/elementary school
# 141912                          Primary/elementary school
# 141913          Other doctoral degree (Ph.D, Ed.D., etc.)
# 141915  Secondary school (e.g. American high school, G...
# 141918  Secondary school (e.g. American high school, G...
# 141919           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141921           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141922  Secondary school (e.g. American high school, G...
# 141923           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 141925        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 141926  Some college/university study without earning ...
# 141927  Some college/university study without earning ...
# 141928        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 141931                          Primary/elementary school
# 141933  Secondary school (e.g. American high school, G...
# 141935                          Primary/elementary school
# 141936        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                            UndergradMajor  \
# 0                                                     NaN
# 1                Computer science or software engineering
# 2                Computer science or software engineering
# 3           A non-computer-focused engineering discipline
# 4                Computer science or software engineering
# 5                                                     NaN
# 6           A non-computer-focused engineering discipline
# 7                Computer science or software engineering
# 8                Computer science or software engineering
# 9                Computer science or software engineering
# 10                                       A social science
# 11               Computer science or software engineering
# 12                              Mathematics or statistics
# 13               Computer science or software engineering
# 14      Computer engineering or electrical/electronics...
# 15                                                    NaN
# 16                                                    NaN
# 17               Computer science or software engineering
# 18               Computer science or software engineering
# 19                                      A natural science
# 20               Computer science or software engineering
# 21                                      A natural science
# 22      Computer engineering or electrical/electronics...
# 23                                                    NaN
# 24               Computer science or software engineering
# 25               Computer science or software engineering
# 26               Computer science or software engineering
# 27                                  A business discipline
# 28      Computer engineering or electrical/electronics...
# 29                                  A business discipline
# ...                                                   ...
# 141892  Another engineering discipline (ex. civil, ele...
# 141893  A business discipline (ex. accounting, finance...
# 141894  Computer science, computer engineering, or sof...
# 141895                                                NaN
# 141896  Computer science, computer engineering, or sof...
# 141897                           I never declared a major
# 141899  A natural science (ex. biology, chemistry, phy...
# 141901  Another engineering discipline (ex. civil, ele...
# 141902  Computer science, computer engineering, or sof...
# 141904  Computer science, computer engineering, or sof...
# 141905  Computer science, computer engineering, or sof...
# 141906  Computer science, computer engineering, or sof...
# 141907                                                NaN
# 141911                                                NaN
# 141912                                                NaN
# 141913  A social science (ex. anthropology, psychology...
# 141915                                                NaN
# 141918                                                NaN
# 141919  Information systems, information technology, o...
# 141921  A business discipline (ex. accounting, finance...
# 141922                                                NaN
# 141923  Another engineering discipline (ex. civil, ele...
# 141925                          Mathematics or statistics
# 141926  A natural science (ex. biology, chemistry, phy...
# 141927  Computer science, computer engineering, or sof...
# 141928  Another engineering discipline (ex. civil, ele...
# 141931                                                NaN
# 141933                                                NaN
# 141935                                                NaN
# 141936  A business discipline (ex. accounting, finance...
#
#                      CompanySize       YearsCoding YearsCodingProf  \
# 0                            NaN         0-2 years             NaN
# 1             20 to 99 employees        9-11 years             NaN
# 2       10,000 or more employees  20 or more years             NaN
# 3       10,000 or more employees       12-14 years             NaN
# 4             10 to 19 employees  20 or more years             NaN
# 5                            NaN         6-8 years             NaN
# 6             20 to 99 employees        9-11 years             NaN
# 7        Fewer than 10 employees        9-11 years             NaN
# 8       5,000 to 9,999 employees       12-14 years             NaN
# 9                            NaN       12-14 years             NaN
# 10          100 to 499 employees       12-14 years             NaN
# 11          100 to 499 employees       12-14 years             NaN
# 12                           NaN  20 or more years     15-17 years
# 13       Fewer than 10 employees       15-17 years             NaN
# 14      5,000 to 9,999 employees  20 or more years             NaN
# 15                           NaN        9-11 years             NaN
# 16                           NaN         6-8 years             NaN
# 17      1,000 to 4,999 employees  20 or more years             NaN
# 18      10,000 or more employees         0-2 years             NaN
# 19       Fewer than 10 employees       12-14 years             NaN
# 20      10,000 or more employees         3-5 years             NaN
# 21            20 to 99 employees  20 or more years             NaN
# 22          500 to 999 employees        9-11 years             NaN
# 23                           NaN        9-11 years             NaN
# 24            20 to 99 employees       18-20 years             NaN
# 25      10,000 or more employees  20 or more years             NaN
# 26      5,000 to 9,999 employees       12-14 years             NaN
# 27          100 to 499 employees         0-2 years             NaN
# 28            10 to 19 employees  20 or more years             NaN
# 29      10,000 or more employees         3-5 years             NaN
# ...                          ...               ...             ...
# 141892                       NaN  20 or more years             NaN
# 141893                       NaN       12-14 years             NaN
# 141894                       NaN  20 or more years             NaN
# 141895                       NaN         3-5 years             NaN
# 141896                       NaN       12-14 years             NaN
# 141897                       NaN  20 or more years             NaN
# 141899                       NaN         6-8 years             NaN
# 141901                       NaN  20 or more years             NaN
# 141902                       NaN  20 or more years             NaN
# 141904                       NaN        9-11 years             NaN
# 141905                       NaN        9-11 years             NaN
# 141906                       NaN         0-2 years             NaN
# 141907                       NaN         0-2 years             NaN
# 141911                       NaN         3-5 years             NaN
# 141912                       NaN         6-8 years             NaN
# 141913                       NaN         3-5 years             NaN
# 141915                       NaN         0-2 years             NaN
# 141918                       NaN         3-5 years             NaN
# 141919                       NaN  20 or more years             NaN
# 141921                       NaN         0-2 years             NaN
# 141922                       NaN         0-2 years             NaN
# 141923                       NaN         3-5 years             NaN
# 141925                       NaN       18-20 years             NaN
# 141926                       NaN         0-2 years             NaN
# 141927                       NaN  20 or more years             NaN
# 141928                       NaN         6-8 years             NaN
# 141931                       NaN         0-2 years             NaN
# 141933                       NaN       12-14 years             NaN
# 141935                       NaN         0-2 years             NaN
# 141936                       NaN  20 or more years             NaN
#
#              ...        Visual_Source_Safe_VC I_don’t_know_Race  \
# 0            ...                        False             False
# 1            ...                        False             False
# 2            ...                        False             False
# 3            ...                        False             False
# 4            ...                        False             False
# 5            ...                        False             False
# 6            ...                        False             False
# 7            ...                        False             False
# 8            ...                        False             False
# 9            ...                        False             False
# 10           ...                        False             False
# 11           ...                        False             False
# 12           ...                        False             False
# 13           ...                        False             False
# 14           ...                        False             False
# 15           ...                        False             False
# 16           ...                        False             False
# 17           ...                        False             False
# 18           ...                        False             False
# 19           ...                        False             False
# 20           ...                        False             False
# 21           ...                        False             False
# 22           ...                        False             False
# 23           ...                        False             False
# 24           ...                        False             False
# 25           ...                        False             False
# 26           ...                        False             False
# 27           ...                        False             False
# 28           ...                        False             False
# 29           ...                        False             False
# ...          ...                          ...               ...
# 141892       ...                        False             False
# 141893       ...                        False             False
# 141894       ...                        False             False
# 141895       ...                        False             False
# 141896       ...                        False             False
# 141897       ...                        False             False
# 141899       ...                        False             False
# 141901       ...                        False             False
# 141902       ...                        False             False
# 141904       ...                        False             False
# 141905       ...                        False             False
# 141906       ...                        False             False
# 141907       ...                        False             False
# 141911       ...                        False             False
# 141912       ...                        False             False
# 141913       ...                        False             False
# 141915       ...                        False             False
# 141918       ...                        False             False
# 141919       ...                        False             False
# 141921       ...                        False             False
# 141922       ...                        False             False
# 141923       ...                        False             False
# 141925       ...                        False             False
# 141926       ...                        False             False
# 141927       ...                        False             False
# 141928       ...                        False             False
# 141931       ...                        False             False
# 141933       ...                        False             False
# 141935       ...                        False             False
# 141936       ...                        False             False
#
#        East_Asian_Race  \
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# 6                False
# 7                False
# 8                False
# 9                False
# 10               False
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16               False
# 17               False
# 18               False
# 19               False
# 20               False
# 21               False
# 22               False
# 23               False
# 24               False
# 25               False
# 26               False
# 27               False
# 28               False
# 29               False
# ...                ...
# 141892           False
# 141893            True
# 141894           False
# 141895           False
# 141896           False
# 141897           False
# 141899           False
# 141901           False
# 141902           False
# 141904           False
# 141905           False
# 141906           False
# 141907           False
# 141911           False
# 141912           False
# 141913           False
# 141915           False
# 141918           False
# 141919           False
# 141921           False
# 141922           False
# 141923           False
# 141925           False
# 141926           False
# 141927           False
# 141928           False
# 141931           False
# 141933           False
# 141935           False
# 141936           False
#
#        Native_American,_Pacific_Islander,_or_Indigenous_Australian_Race  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# 5                                                   False
# 6                                                   False
# 7                                                   False
# 8                                                   False
# 9                                                   False
# 10                                                  False
# 11                                                  False
# 12                                                  False
# 13                                                  False
# 14                                                  False
# 15                                                  False
# 16                                                  False
# 17                                                   True
# 18                                                  False
# 19                                                  False
# 20                                                  False
# 21                                                  False
# 22                                                  False
# 23                                                  False
# 24                                                  False
# 25                                                  False
# 26                                                  False
# 27                                                  False
# 28                                                  False
# 29                                                  False
# ...                                                   ...
# 141892                                              False
# 141893                                               True
# 141894                                              False
# 141895                                              False
# 141896                                              False
# 141897                                               True
# 141899                                              False
# 141901                                              False
# 141902                                              False
# 141904                                              False
# 141905                                              False
# 141906                                              False
# 141907                                              False
# 141911                                              False
# 141912                                              False
# 141913                                              False
# 141915                                              False
# 141918                                              False
# 141919                                              False
# 141921                                              False
# 141922                                              False
# 141923                                              False
# 141925                                              False
# 141926                                              False
# 141927                                              False
# 141928                                              False
# 141931                                              False
# 141933                                              False
# 141935                                              False
# 141936                                              False
#
#        Black_or_of_African_descent_Race Middle_Eastern_Race  \
# 0                                 False               False
# 1                                 False               False
# 2                                 False               False
# 3                                 False               False
# 4                                 False               False
# 5                                 False               False
# 6                                 False               False
# 7                                 False               False
# 8                                 False               False
# 9                                 False               False
# 10                                False               False
# 11                                False               False
# 12                                False               False
# 13                                False               False
# 14                                False               False
# 15                                False               False
# 16                                False               False
# 17                                False               False
# 18                                False               False
# 19                                False               False
# 20                                False               False
# 21                                False               False
# 22                                False               False
# 23                                False               False
# 24                                False               False
# 25                                False               False
# 26                                False               False
# 27                                False               False
# 28                                False               False
# 29                                False               False
# ...                                 ...                 ...
# 141892                            False               False
# 141893                             True                True
# 141894                            False               False
# 141895                            False               False
# 141896                            False               False
# 141897                            False               False
# 141899                            False               False
# 141901                            False               False
# 141902                            False               False
# 141904                            False               False
# 141905                            False               False
# 141906                            False               False
# 141907                            False               False
# 141911                            False               False
# 141912                             True               False
# 141913                            False                True
# 141915                            False               False
# 141918                            False               False
# 141919                            False               False
# 141921                            False               False
# 141922                            False               False
# 141923                            False               False
# 141925                            False               False
# 141926                            False               False
# 141927                            False               False
# 141928                            False               False
# 141931                            False               False
# 141933                            False               False
# 141935                            False               False
# 141936                            False               False
#
#        Hispanic_or_Latino/Latina_Race White_or_of_European_descent_Race  \
# 0                               False                              True
# 1                               False                              True
# 2                               False                              True
# 3                               False                              True
# 4                               False                             False
# 5                               False                              True
# 6                               False                              True
# 7                               False                              True
# 8                                True                             False
# 9                               False                              True
# 10                              False                              True
# 11                              False                             False
# 12                              False                              True
# 13                               True                             False
# 14                              False                              True
# 15                              False                              True
# 16                              False                              True
# 17                              False                              True
# 18                              False                             False
# 19                              False                             False
# 20                              False                             False
# 21                              False                              True
# 22                              False                              True
# 23                              False                              True
# 24                              False                             False
# 25                              False                              True
# 26                              False                             False
# 27                              False                             False
# 28                              False                              True
# 29                              False                             False
# ...                               ...                               ...
# 141892                          False                             False
# 141893                           True                              True
# 141894                          False                             False
# 141895                          False                              True
# 141896                          False                              True
# 141897                          False                             False
# 141899                          False                             False
# 141901                          False                              True
# 141902                          False                             False
# 141904                          False                             False
# 141905                          False                             False
# 141906                          False                             False
# 141907                          False                              True
# 141911                          False                              True
# 141912                          False                             False
# 141913                          False                             False
# 141915                          False                              True
# 141918                          False                              True
# 141919                          False                              True
# 141921                          False                              True
# 141922                          False                              True
# 141923                          False                             False
# 141925                          False                             False
# 141926                           True                             False
# 141927                          False                              True
# 141928                          False                              True
# 141931                          False                             False
# 141933                          False                             False
# 141935                          False                             False
# 141936                          False                             False
#
#        I_prefer_not_to_say_Race South_Asian_Race
# 0                         False            False
# 1                         False            False
# 2                         False            False
# 3                         False            False
# 4                         False            False
# 5                         False            False
# 6                         False            False
# 7                         False            False
# 8                         False            False
# 9                         False            False
# 10                        False            False
# 11                        False            False
# 12                        False            False
# 13                        False            False
# 14                        False            False
# 15                        False            False
# 16                        False            False
# 17                        False            False
# 18                        False            False
# 19                         True            False
# 20                        False            False
# 21                        False            False
# 22                        False            False
# 23                        False            False
# 24                        False            False
# 25                        False            False
# 26                        False            False
# 27                        False            False
# 28                        False            False
# 29                        False            False
# ...                         ...              ...
# 141892                    False            False
# 141893                    False             True
# 141894                    False            False
# 141895                    False            False
# 141896                    False            False
# 141897                    False            False
# 141899                    False             True
# 141901                    False            False
# 141902                    False            False
# 141904                    False             True
# 141905                    False            False
# 141906                    False            False
# 141907                    False            False
# 141911                    False            False
# 141912                    False            False
# 141913                    False            False
# 141915                    False            False
# 141918                    False            False
# 141919                    False            False
# 141921                    False            False
# 141922                    False            False
# 141923                    False             True
# 141925                    False            False
# 141926                    False            False
# 141927                    False            False
# 141928                    False            False
# 141931                    False             True
# 141933                    False             True
# 141935                    False            False
# 141936                    False            False
#
# [128450 rows x 325 columns]

# %% [markdown]
# ## Visualizaciones

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
def heatmap(data, row_labels, col_labels, ax=None,
            cbar_kw={}, cbarlabel="", **kwargs):
    if not ax:
        ax = plt.gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=-30, ha="right",
             rotation_mode="anchor")

    # Turn spines off and create white grid.
    for edge, spine in ax.spines.items():
        spine.set_visible(False)

    ax.set_xticks(np.arange(data.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)

    return im, cbar


def annotate_heatmap(im, data=None, valfmt="{x:.2f}",
                     textcolors=["black", "white"],
                     threshold=None, **textkw):

    if not isinstance(data, (list, np.ndarray)):
        data = im.get_array()

    # Normalize the threshold to the images color range.
    if threshold is not None:
        threshold = im.norm(threshold)
    else:
        threshold = im.norm(data.max())/2.

    # Set default alignment to center, but allow it to be
    # overwritten by textkw.
    kw = dict(horizontalalignment="center",
              verticalalignment="center")
    kw.update(textkw)

    # Get the formatter in case a string is supplied
    if isinstance(valfmt, str):
        valfmt = matplotlib.ticker.StrMethodFormatter(valfmt)

    # Loop over the data and create a `Text` for each "pixel".
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            kw.update(color=textcolors[im.norm(data[i, j]) > threshold])
            text = im.axes.text(j, i, valfmt(data[i, j], None), **kw)
            texts.append(text)

    return texts

# %%
devtypes = set()
for x in df2018['DevType']:
    if isinstance(x, str):
        devtypes.update(x.split(";"))

dt = df.iloc[:,22:52]
dt

devtypes = dt.columns.unique()

langs = df.iloc[:,53:95]
languages = ['JavaScript', 'HTML', 'SQL', 'Java', 'C', 'PHP', 'Python', 'Objective-C', 'C++', 'Ruby']

qty = list()
for d_type in devtypes:
    info = list()
    
    for language in languages:
        d = df[df[d_type]==True]
        d = d[d[language+"_Worked"]==True]
        info.append(d[language+"_Worked"].count())
    suma = np.sum(info)
    info = [x/suma for x in info]
    qty.append(info)

qty = np.array(qty)

# %%
fig, ax = plt.subplots()
fig.set_figheight(20)
fig.set_figwidth(100)

im, cbar = heatmap(qty, devtypes, languages, ax=ax,
                   cmap="PuBu", cbarlabel="Languages Worked With")
texts = annotate_heatmap(im)

fig.tight_layout()
plt.show()

# %%
d_langs = df.iloc[:,95:137]
d_languages = ['JavaScript', 'HTML', 'SQL', 'Java', 'C', 'PHP', 'Python', 'Objective-C', 'C++', 'Ruby']

qty2 = list()
for d_type in devtypes:
    info = list()
    
    for language in d_languages:
        d = df[df[d_type]==True]
        d = d[d[language+"_Desire"]==True]
        info.append(d[language+"_Desire"].count())
    suma = np.sum(info)
    info = [x/suma for x in info]
    qty2.append(info)

qty2 = np.array(qty2)

# %%
fig, ax = plt.subplots()
fig.set_figheight(20)
fig.set_figwidth(100)

im, cbar = heatmap(qty2, devtypes, d_languages, ax=ax,
                   cmap="PuBu", cbarlabel="Language Desire")
texts = annotate_heatmap(im)

fig.tight_layout()
plt.show()

# %%
labels = devtypes

fracs = []


di = dict()

for t in labels:
    d = df[df['YearsCoding']=='20 or more years']
    d = d[d[t]==True]
    c = d[t].count()
    fracs.append(c)
    di[t] = c

labels = sorted(labels, key=lambda x:di[x], reverse=True)
fracs = [di[x] for x in labels]

labels = labels[:10]
fracs = fracs[:10]
explode=[0 for _ in labels]
explode[0] = 0.1

fig1, ax1 = plt.subplots()
fig1.set_figheight(10)
fig1.set_figwidth(15)
ax1.pie(fracs, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
labels = devtypes

fracs = []


di = dict()

for t in labels:
    d = df[df['YearsCoding']=='0-2 years']
    d = d[d[t]==True]
    c = d[t].count()
    fracs.append(c)
    di[t] = c

labels = sorted(labels, key=lambda x:di[x], reverse=True)
fracs = [di[x] for x in labels]

labels = labels[:10]
fracs = fracs[:10]
explode=[0 for _ in labels]
explode[0] = 0.1

fig1, ax1 = plt.subplots()
fig1.set_figheight(10)
fig1.set_figwidth(15)
ax1.pie(fracs, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Modelo de Clasificación
# ## Random Forest

# %%
langs.columns.unique()
# Out:
# Index(['Cobol_Worked', 'C_Worked', 'Java_Worked', 'Objective-C_Worked',
#        'Go_Worked', 'Elixir_Worked', 'SQL_Worked', 'CSS_Worked', 'F#_Worked',
#        'HTML_Worked', 'Swift_Worked', 'C++_Worked', 'Visual_Basic_6_Worked',
#        'Scala_Worked', 'R_Worked', 'Hack_Worked', 'Lua_Worked',
#        'Smalltalk_Worked', 'Perl_Worked', 'Clojure_Worked',
#        'Delphi/Object_Pascal_Worked', 'VBA_Worked', 'Ruby_Worked',
#        'Common_Lisp_Worked', 'VB.NET_Worked', 'Python_Worked',
#        'Bash/Shell_Worked', 'Julia_Worked', 'Haskell_Worked', 'Kotlin_Worked',
#        'Rust_Worked', 'JavaScript_Worked', 'Ocaml_Worked', 'C#_Worked',
#        'Erlang_Worked', 'Groovy_Worked', 'PHP_Worked', 'Matlab_Worked',
#        'CoffeeScript_Worked', 'Assembly_Worked', 'Dart_Worked',
#        'TypeScript_Worked'],
#       dtype='object')

# %%
df["YearsCoding"].unique()
# Out:
# array(['0-2 years', '9-11 years', '20 or more years', '12-14 years',
#        '6-8 years', '15-17 years', '3-5 years', '18-20 years', nan], dtype=object)
